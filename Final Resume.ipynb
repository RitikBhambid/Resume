# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python.'
Name = 'RITIK BHAMBID'
Title = 'Python | Data Science | ML'
Contact_header="Contact"
Contact_desc= 'Pune'
Contact_num ='Contact Number :-9637185127'
Contact_desc_Mail_head='Email'
Contact_desc_linkdin_head='LinkedIn'
Contact_desc_github_head='github'
Contact_desc_Mail='ritikbhambid@gmail.com'
Contact_desc_linkdin='linkedin.com/in/ritik-bhambid/'
Contact_desc_github='github.com/RitikBhambid'
knowledge='Knowledge'
knowledge_desc='Cloud: AWS,Heroku\nBI Tools: Power BI,Tableau\nFramework : flask'

SummaryHeader = 'Summary'
summary_desk ="""
Data Science enthusiastic with ongoing internship experience \n-pragmatic, result-oriented with strong ethical values,\n adaptable with any working environment."""

ProjectHeader = 'Projects'
ProjectOneTitle = 'Review Scraping from flipcart'
ProjectOneDesc ='- https://flipcartscraper.herokuapp.com/\n- https://github.com/RitikBhambid/Review-Scraping-from-flipcart\n- Find eny product reviw\n- Without any human interface\n- Flask framework\n- End to end project written in python'
ProjectTwoTitle='Chat bot using python'
ProjectTwoDesc ='- https://github.com/RitikBhambid/chat-bot\n- The objective is to develop artificial assistance for doing a sum of tasks using voice\n    commands and interacting with humans. Like open youtube, what is time , send mail.\n- Lead a Team of 4 and Developed this project using libraries\n  like pyttsx3,speech_recognition,smtplib\n- Role Played during is model creation,Testing ad Debugging.'
ProjectThreeTitle = 'Cab Fare Prediction'
ProjectThreeDesc = '- https://github.com/RitikBhambid/Cab-Fare-Prediction\n-The objective of this project is to design a system that predicts\n the fare amount for a cab ride in the city\n-Developed this project using libraries like numpy,pandas,sklearn.\n-Work is ongoin on this project'

EduHeader = 'Education'
EduOneTitle = 'Computer Engineering'
EduOnePercentage = 'Percentage 82.24'
EduOneTime = '2018-2021(82.24%)'
EduOneDesc = 'Maharashtra polytechnic                                       Ratnagiri, India '
EduTwoTitle = 'MARSIAN Technologies (marsiantech.com)'
EduTwoTime = 'October 2021 - May 2022'
EduTwoDesc = 'Data Science certification training                            Pune, India'

SkillsHeader = 'Technical Skills'
SkillsDesc ="""- Machine Learning
     . Linear Regression
     . Logistic Regression
     . Decision Tree
     . Support Vector Machine
     . Naive Bayes
     . K-nearest neighbor
     . K-Means
     . Random Forest
     . Principal component analysis
     . XGBoost"""

SkillsTwoDesc ="""- Descriptive & Inferencial Statistics
     . Probability
     . Probability distribution
     . Hypothetical Testing
     . Test of Hypothesis
     . ANOVA(Analysis of Variance)"""

SkillsOneDesc = '- Python\n- Data Exploration\n- Pandas\n- NumPy\n- SKlearn\n- Git \n- SQL\n- API\n- Excel for statistical analysis '
ExtrasTitle = 'DataQuest\nData Scientist Path'
ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.9, 11))


# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='green',alpha=0.0,  linewidth=50)  
plt.axvline(x=.0, color='#9abaf5',alpha=0.5,  linewidth=320)               
plt.axhline(y=.91, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=.89, xmin=0.0, xmax=0.3, color='#2884ed', linewidth=20)
plt.axhline(y=.60, xmin=0.0, xmax=0.3, color='#2884ed', linewidth=20)
plt.axhline(y=.08, xmin=0.0, xmax=0.3, color='#2884ed', linewidth=19)
plt.axhline(y=.91, xmin=0.34, xmax=.95, color='black', linewidth=1) #horizontal line
plt.axhline(y=.76, xmin=0.34, xmax=.95, color='black', linewidth=1) #horizontal line
plt.axhline(y=.26, xmin=0.34, xmax=.95, color='black', linewidth=1) #horizontal line


# set background color
ax.set_facecolor('white')


# add text
plt.annotate(Header, (.33,.98), weight='regular', fontsize=8, alpha=.75)
plt.annotate(Name, (.01,.960), weight='bold', fontsize=15,color='white')
plt.annotate(Title, (.01,.93), weight='regular', fontsize=13, color='white')
plt.annotate(Contact_header, (.09,.88), weight='bold', fontsize=16, color='#ffffff')
plt.annotate("Address", (.01,.85), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc, (.020,.83), weight='regular', fontsize=10, color='black')
plt.annotate(Contact_num, (.020,.81), weight='regular', fontsize=10, color='black')
plt.annotate(Contact_desc_Mail_head, (.01,.77), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_linkdin_head, (.01,.71), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_github_head, (.01,.65), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_Mail, (.020,.75), weight='regular', fontsize=10, color='black')
plt.annotate(Contact_desc_linkdin, (.020,.69), weight='regular', fontsize=10, color='black')
plt.annotate(Contact_desc_github, (.020,.63), weight='regular', fontsize=10, color='black')
plt.annotate(knowledge, (.07,.07), weight='bold', fontsize=16, color='#ffffff')
plt.annotate(knowledge_desc, (.020,.01), weight='regular', fontsize=10, color='black')
plt.annotate(SkillsHeader, (.04,.59), weight='bold', fontsize=16, color='#ffffff')
plt.annotate(SkillsOneDesc, (.01,.10), weight='regular', fontsize=10, color='black')
plt.annotate(SkillsDesc, (.01,.38), weight='regular', fontsize=10, color='black')
plt.annotate(SummaryHeader, (.34,.93), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(summary_desk, (.34,.84), weight='regular', fontsize=10)
plt.annotate(ProjectHeader, (.34,.78), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(ProjectOneTitle, (.35,.72), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.35,.62), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.35,.57), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.35,.47), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.35,.42), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.35,.34), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.35,.28), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(EduOneTitle, (.35,.22), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.35,.2), weight='regular', fontsize=9, alpha=.6)
plt.annotate(SkillsTwoDesc, (.01,.27), weight='regular', fontsize=10, color='black')

plt.annotate(EduOneDesc, (.35,.18), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.35,.1), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.35,.079), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoDesc, (.35,.061), weight='regular', fontsize=9)

# remove axes
plt.axis('off')

plt.savefig('Ritik_Bhambid.pdf', dpi=300, bbox_inches='tight')
