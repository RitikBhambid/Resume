# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python.'
Name = 'RITIK BHAMBID'
Title = 'Python | Data Science | ML'
Contact_header="Contacts"
Contact_desc= 'Pune'
Contact_num ='Contact Number :-9637185127'
Contact_desc_Mail_head='Email'
Contact_desc_linkdin_head='LinkedIn'
Contact_desc_github_head='github'
Contact_desc_Mail='ritikbhambid@gmail.com'
Contact_desc_linkdin='linkedin.com/in/ritik-bhambid/'
Contact_desc_github='github.com/RitikBhambid'
knowledge='knowledge'
knowledge_desc=' Database: SQL \n\n Cloud: AWS,Heroku\n\n BI Tools: Power BI,Tableau \n\n Framework : flask'

SummaryHeader = 'Summary'
summary_desk ="""I am a Data Science enthusiast who has been trying to explore this domain 
for the past 6 months.
I am having Internship experience of more than 1 week in the data science 
domain. 
I am quite an accountable, result-oriented and pragmatic person with strong 
ethical values.
The best part about me is that I adapt myself to any environment placed."""

ProjectHeader = 'Personal Project'
ProjectOneTitle = 'Review Scraping from flipcart'
ProjectOneDesc ='- https://flipcartscraper.herokuapp.com/\n- https://github.com/RitikBhambid/Review-Scraping-from-flipcart\n- Find eny product reviw\n- Without any human interface\n- Flask framework\n- End to end project written in python'
ProjectTwoTitle='Chat bot using python'
ProjectTwoDesc ='- https://github.com/RitikBhambid/chat-bot\n- Lead a Team of 4 and Developed this project using libraries using libraries\n  like pyttsx3,speech_recognition,smtplib\n- Role Played during is model creation,Testing ad Debugging.'
ProjectThreeTitle = 'Cab Fare Prediction'
ProjectThreeDesc = '- https://github.com/RitikBhambid/Cab-Fare-Prediction\n-The objective of this project is to design a system that predicts\n the fare amount for a cab ride in the city\n-Developed this project using libraries like numpy,pandas,sklearn.\n-Work is ongoin on this project'

EduHeader = 'Education'
EduOneTitle = 'Computer Engineering'
EduOneTime = '2018-2021'
EduOneDesc = 'Maharashtra polytechnic                                       Ratnagiri, India '
EduTwoTitle = 'Martian Technologies'
EduTwoTime = '2021-Present'
EduTwoDesc = 'data science                                                           Pune, India'

SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Pandas\n- NumPy\n- sklearn\n- Data Visualization\n- Git \n- SQL\n- API\n- Probability/Statistics\n- Data Manipulation\n- Excel'
ExtrasTitle = 'DataQuest\nData Scientist Path'
ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 11))


# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='green',alpha=0.0,  linewidth=50)  
plt.axvline(x=.0, color='#4974f5',alpha=0.5,  linewidth=300)               
plt.axhline(y=.89, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=.86, xmin=0.0, xmax=0.29, color='#2884ed', linewidth=20)
plt.axhline(y=.51, xmin=0.0, xmax=0.29, color='#2086fa', linewidth=20)
plt.axhline(y=.21, xmin=0.0, xmax=0.29, color='#10b0e6', linewidth=20)
plt.axhline(y=.91, xmin=0.34, xmax=.95, color='black', linewidth=1) #horizontal line
plt.axhline(y=.71, xmin=0.34, xmax=.95, color='black', linewidth=1) #horizontal line
plt.axhline(y=.22, xmin=0.34, xmax=.95, color='black', linewidth=1) #horizontal line


# set background color
ax.set_facecolor('white')


# add text
plt.annotate(Header, (.33,.98), weight='regular', fontsize=8, alpha=.75)
plt.annotate(Name, (.01,.960), weight='bold', fontsize=15,color='white')
plt.annotate(Title, (.01,.92), weight='regular', fontsize=13, color='white')
plt.annotate(Contact_header, (.04,.85), weight='bold', fontsize=16, color='#ffffff')
plt.annotate("Address", (.01,.81), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc, (.020,.79), weight='regular', fontsize=10, color='black')
plt.annotate(Contact_num, (.020,.76), weight='regular', fontsize=10, color='black')
plt.annotate(Contact_desc_Mail_head, (.01,.73), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_linkdin_head, (.01,.66), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_github_head, (.01,.60), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_Mail, (.020,.70), weight='regular', fontsize=10, color='black')
plt.annotate(Contact_desc_linkdin, (.020,.63), weight='regular', fontsize=10, color='black')
plt.annotate(Contact_desc_github, (.020,.57), weight='regular', fontsize=10, color='black')
plt.annotate(knowledge, (.04,.2), weight='bold', fontsize=16, color='#ffffff')
plt.annotate(knowledge_desc, (.020,.04), weight='regular', fontsize=10, color='black')
plt.annotate(SkillsHeader, (.04,.5), weight='bold', fontsize=16, color='#ffffff')
plt.annotate(SkillsDesc, (.01,.26), weight='regular', fontsize=10, color='black')
plt.annotate(SummaryHeader, (.34,.93), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(summary_desk, (.34,.77), weight='regular', fontsize=10)
plt.annotate(ProjectHeader, (.34,.72), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(ProjectOneTitle, (.35,.68), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.35,.58), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.35,.53), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.35,.46), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.35,.4), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.35,.31), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.35,.23), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(EduOneTitle, (.35,.18), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.35,.16), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.35,.14), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.35,.08), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.35,.065), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoDesc, (.35,.048), weight='regular', fontsize=9)

# remove axes
plt.axis('off')

plt.savefig('Final_Resume.pdf', dpi=300, bbox_inches='tight')
