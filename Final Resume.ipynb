# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python.'
Name = 'RITIK BHAMBID'
Title = '| Data Science | ML | DL |' 
Contact_header="Contact"
Contact_desc= 'Pune'
Contact_num ='Contact Number :-9637185127'
Contact_desc_Mail_head='Email'
Contact_desc_linkdin_head='LinkedIn'
Contact_desc_github_head='Github'
Contact_desc_Mail='ritikbhambid@gmail.com'
Contact_desc_linkdin='linkedin.com/in/ritik-bhambid/'
Contact_desc_github='github.com/RitikBhambid'
knowledge='Knowledge'
knowledge_desc='Cloud: AWS,Heroku\n\nBI Tools: Power BI,Tableau\n\nFramework : flask \n\nIDE : pyCharm,VScode,\n\n        Google Colaboratory'

SummaryHeader = 'Summary'
summary_desk ="""
Data Science enthusiastic  with  ongoing internship experience, Working  experience in computer vision, natural\n language processing. Hands-on experience leveraging machine learning, deep learning,transfer learning, models\n to solve challenging business problems """

ProjectHeader = 'Projects'
ProjectOneTitle = 'Thyroid Detection'
ProjectOneDesc ='''▫  The project aims to build a predictive system that will tell whether patients have highchances of thyroid disease
    or fewer chances of thyroid disease.
▫  The thyroid is an endocrine gland  found in the neck whose function is to produce hormones (FT3 and FT4)
    whichit releases into the bloodstream.
▫  The thyroid gland may function more than normal( hyperthyroidism with increased hormones ) or less than 
    normal ( hypothyroidism with low hormones ) in both cases major disorders can occur. 
▫  For this reason treatment of thyroid diseases is very important.\n
     Tech Stack: Streamlit , Random Forest, Scikit-Learn, Docker, GitHub, Heroku, PyCharm ,CircleCi ,mlops using\n       MLflow etc.\n     Webapp Link : https://thyroiddetection10.herokuapp.com \n     GitHub Link : https://github.com/RitikBhambid/ThyroidDetection'''

ProjectOneDesc1 ="""⤜ Other Skills: All phases of the software development life-cycle (requirement gathering, Architechture Design,
      Process flow, HLD, LLD , Deployment, testing, CI/CD pipeline) , Modular Coding (OOPs).
⤜ Possess good interpersonal skills that have been put to  good use in co-coordinating with Project teams and
      providing customized software solutions.
⤜ Effective communication skills and proven abilities in resolving complex issues. 
"""








ProjectTwoTitle='Facial recognition system'
ProjectTwoDesc ="""▫ The objective is to recognize the human face in a fraction of seconds using any High definition camera
▫  We use a pre-trained transfer learning approach MTCNN for detecting human faces
▫  Simply create a dataset, where we will store for each id, a group of photos in gray that was used for face recognition.
▫  Capture a fresh face on our camera and if this person had his face captured and trained before, our recognizer will\n    make a “prediction” returning its id and an index, shown how confident the recognizer is with this match.
▫  put a text over the image with the probable id and how much is the “probability”in % that the match is correct\n   (“probability” = 100 — confidence index). If not, an “unknow” label is put on the face.
"""
ProjectTwoDesc1='Tech Stack : Python,MXNET, Keras,Tkinter, OpenCV,MTCNN,Arcface etc.\nGitHub Link :https://github.com/RitikBhambid/face-recognition'


ProjectThreeTitle = 'spelling-corrector'
ProjectThreeDesc = """▫ A word needs to be checked for spelling correctness and corrected if necessary, many a time in the context of the\n    surrounding words.
▫ A spellchecker points to spelling errors and possibly suggests alternatives. 
▫ An autocorrector usually goes a step further and automatically picks the most likely word.
▫ In this project Symmetric Delete spelling correction algorithm is used to reduces the complexity of edit candidate\n    generation and dictionary lookup for a given Damerau-Levenshtein distance."""
ProjectThreeDesc1='Tech Stack :Python, symspellpy, frequency bigramdictionary, editdistance, editdistance, Damerau-Levenshtein\nGitHub Link :https://github.com/RitikBhambid/spelling-corrector'

EduHeader = 'Technical Education'
EduOneTitle = 'Computer Engineering'
EduOnePercentage = 'Percentage 82.24'
EduOneTime = '2018-2021(82.24%)'
EduOneDesc = 'Maharashtra polytechnic                                                           Ratnagiri, India '
EduTwoTitle = 'Data Science certification training'
EduTwoTime = 'October 2021 - May 2022'
EduTwoDesc = 'MARSIAN Technologies (marsiantech.com)                            Pune, India'

SkillsHeader = 'Skills'
SkillsDesc =" . Python \n . Web scraping \n . Machine learning \n . Deep Learning \n . Computer Vision  \n . Natural Language Processing\n . Statistical analysis\n . Data Visualization\n . Data Wrangling\n . Excel "  
    

#SkillsTwoDesc ="""- Descriptive & Inferencial Statistics
#      . Probability
#      . Probability distribution
#      . Hypothetical Testing
#      . Test of Hypothesis
#      . ANOVA(Analysis of Variance)"""

# SkillsOneDesc = '- Python\n- Data Exploration\n- Pandas\n- NumPy\n- SKlearn\n- Git \n- SQL\n- API\n- Excel for statistical analysis '
# ExtrasTitle = 'DataQuest\nData Scientist Path'
# ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
# CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(11, 13))


# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='green',alpha=0.0,  linewidth=50)  
plt.axvline(x=.0, color='#9abaf5',alpha=0.5,  linewidth=340)               
plt.axhline(y=.91, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=.89, xmin=0.0, xmax=0.26, color='#2884ed', linewidth=17)
plt.axhline(y=.59, xmin=0.0, xmax=0.26, color='#2884ed', linewidth=17)
plt.axhline(y=.34, xmin=0.0, xmax=0.26, color='#2884ed', linewidth=17)
plt.axhline(y=.93, xmin=0.3, xmax=.95, color='black', linewidth=1) #horizontal line
plt.axhline(y=.83, xmin=0.3, xmax=.95, color='black', linewidth=1) #horizontal line
plt.axhline(y=.16, xmin=0.3, xmax=.95, color='black', linewidth=1) #horizontal line


# set background color
ax.set_facecolor('white')


# add text
plt.annotate(Header, (.3,.98), weight='regular', fontsize=8, alpha=.75)
plt.annotate(Name, (.01,.960), weight='bold', fontsize=15,color='white')
plt.annotate(Title, (.01,.93), weight='regular', fontsize=13, color='white')
plt.annotate(Contact_header, (.09,.88), weight='bold', fontsize=16, color='#ffffff')
plt.annotate("Address", (.01,.85), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc, (.020,.83), weight='regular', fontsize=12, color='black')
plt.annotate(Contact_num, (.020,.81), weight='regular', fontsize=12, color='black')
plt.annotate(Contact_desc_Mail_head, (.01,.77), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_linkdin_head, (.01,.71), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_github_head, (.01,.65), weight='bold', fontsize=12, color='black')
plt.annotate(Contact_desc_Mail, (.020,.75), weight='regular', fontsize=12, color='black')
plt.annotate(Contact_desc_linkdin, (.020,.69), weight='regular', fontsize=12, color='black')
plt.annotate(Contact_desc_github, (.020,.63), weight='regular', fontsize=12, color='black')
plt.annotate(knowledge, (.07,.33), weight='bold', fontsize=16, color='#ffffff')
plt.annotate(knowledge_desc, (.020,.14), weight='regular', fontsize=12, color='black')
plt.annotate(SkillsHeader, (.1,.58), weight='bold', fontsize=16, color='#ffffff')
# plt.annotate(SkillsOneDesc, (.01,.10), weight='regular', fontsize=10, color='black')
plt.annotate(SkillsDesc, (0.01,0.38), weight='regular', fontsize=12, color='black')
plt.annotate(SummaryHeader, (.3,.94), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(summary_desk, (.3,.88), weight='regular', fontsize=9,linespacing=1.4)
plt.annotate(ProjectHeader, (.3,.84), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(ProjectOneTitle, (.3,.8), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.3,.62), weight='regular', fontsize=9,linespacing=1.3)
plt.annotate(ProjectOneDesc1, (.3,.52), weight='regular', fontsize=9,linespacing=1.4)
plt.annotate(ProjectTwoTitle, (.3,.51), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.3,.38), weight='regular', fontsize=9,linespacing=1.4)
plt.annotate(ProjectTwoDesc1, (.3,.36), weight='regular', fontsize=9,linespacing=1.5)
plt.annotate(ProjectThreeTitle, (.3,.33), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.3,.23), weight='regular', fontsize=9,linespacing=1.4)
plt.annotate(ProjectThreeDesc1, (.3,.197), weight='regular', fontsize=9,linespacing=1.5)
plt.annotate(EduHeader, (.3,.17), weight='bold', fontsize=12, color='#2884ed')
plt.annotate(EduOneTitle, (.3,.14), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.3,.12), weight='regular', fontsize=9, alpha=.6)
# plt.annotate(SkillsTwoDesc, (.01,.27), weight='regular', fontsize=10, color='black')

plt.annotate(EduOneDesc, (.3,.090), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.3,.059), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.3,.040), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoDesc, (.3,.015), weight='regular', fontsize=9)

# remove axes
plt.axis('off')

plt.savefig('Ritik_Bhambid.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ####
